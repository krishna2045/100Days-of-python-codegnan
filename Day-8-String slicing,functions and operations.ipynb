# %%
s="codegnan"
print(s[0])
print(s[2])
print(s[5])
print(s[-1])
# Out:
# c
# d
# n
# n

# %%
s[1:]
# Out:
# 'odegnan'

# %%
s[1:5:1]
# Out:
# 'odeg'

# %%
s[1:6:2]
# Out:
# 'oen'

# %%
s[0:4]
# Out:
# 'code'

# %%
s[-5:-1:1]
# Out:
# 'egna'

# %%
s[-1:-5:-1]
# Out:
# 'nang'

# %%
s[:5]
# Out:
# 'codeg'

# %%
s[5:]
# Out:
# 'nan'

# %%
s[:]
# Out:
# 'codegnan'

# %%
s[::-1]
# Out:
# 'nangedoc'

# %%
#String operations:
#concatentation
#string repet
s1="code"
s2="Gnan"
s=s1+" "+s2
print(s)
print(s1+s1+s1)
# Out:
# code Gnan
# codecodecode

# %%
#update c place z
s="codegnan"
print(s[0])
print('z'+s[1:])
print(s)
# Out:
# c
# zodegnan
# codegnan

# %%
s="codegnan"
print(s[0])
print('z'+s[1:])
x='z'+s[1:]
print(x,s)
# Out:
# c
# zodegnan
# zodegnan codegnan

# %%
#string repete
print(s*3)
# Out:
# codegnancodegnancodegnan

# %%
s="codegnan"
print((s+" ")*3)
# Out:
# codegnan codegnan codegnan

# %%
#String functions:
#Case conversion functions:
#Lower(),uppper(),title(),swapcase(),captialize()
s="My name is G krishna"
print(s.lower())
print(s.upper())
print(s.title())
print(s.swapcase())
print(s.capitalize())
# Out:
# my name is g krishna
# MY NAME IS G KRISHNA
# My Name Is G Krishna
# mY NAME IS g KRISHNA
# My name is g krishna

# %%
#Substring index finding
#find(),index()
s="I am python Batch student"
print(s.find("t"))
# Out:
# 7

# %%
s="I am python batch student"
print(s.find("t"))
print(s.find('t',10))
# Out:
# 7
# 14

# %%
#strip-leftstrip and rightstrip
s="       codegnan         "
print(s.strip())
# Out:
# codegnan

# %%
print(s.lstrip())
# Out:
# codegnan

# %%
print(s.rstrip())
# Out:
#        codegnan

# %%
s="$$$$$code$$gnan"
print(s.strip())
# Out:
# $$$$$code$$gnan

# %%
print(s.lstrip())
# Out:
# $$$$$code$$gnan

# %%
print(s.strip('$'))
print(s.lstrip())
print(s.rstrip())
# Out:
# code$$gnan
# $$$$$code$$gnan
# $$$$$code$$gnan

# %%
#split-it returns the list of substrings and its sperates the string with separate
s="@@@@@code@@gnan@@@@@"
print(s)
print(s.split())
print(s.split('@'))
print(s.split('n'))
# Out:
# @@@@@code@@gnan@@@@@
# ['@@@@@code@@gnan@@@@@']
# ['', '', '', '', '', 'code', '', 'gnan', '', '', '', '', '']
# ['@@@@@code@@g', 'a', '@@@@@']

# %%
#find and index
s="my self krishna"
print(s.find('e'))
print(s.find('z'))    #-1print default
# Out:
# 4
# -1

# %%
#index()
print(s.index('f'))
# Out:
# 6

# %%
#case check functions:isupper(),islower(),isdigit(),isalpha(),isalnum()
s1="code"
s2="GNAN"
s3="123"
s4="abc123"
s5="Codeganan"
print(s1.islower())
print(s1.isupper())
print(s2.isupper())
print(s2.islower())
print(s3.isdigit())
print(s3.isalnum())
print(s4.isalnum())
print(s4.isdigit())
print(s5.isalpha())
print(s5.isdigit())
# Out:
# True
# False
# True
# False
# True
# True
# True
# False
# True
# False

# %%
#replace()
s="krishna,sai"
v=s.replace("sai","sai_varma")
print(v)
# Out:
# krishna,sai_varma
